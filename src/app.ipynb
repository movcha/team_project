# %% [markdown]
# Visualization 1:

# %% [markdown]
# Risk Profile Dashboard:
#
# An interactive dashboard where users can select different loan attributes (e.g., income category, home ownership, loan term) and see how these factors affect loan conditions.
#
# We can use filters, sliders, and drop-down menus for user interaction to explore various scenarios and understand the impact of different variables on loan risk.

# %%
pip install pandas dash plotly
# Out:
# Requirement already satisfied: pandas in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (2.2.2)
# Requirement already satisfied: dash in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (2.17.1)
# Requirement already satisfied: plotly in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (5.23.0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from dash) (8.2.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from dash) (2.32.3)
# Requirement already satisfied: retrying in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from dash) (69.5.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from plotly) (24.1)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (1.8.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from importlib-metadata->dash) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from Werkzeug<3.1->dash) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from requests->dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from requests->dash) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from requests->dash) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\omovc\.conda\envs\dsi_participant\lib\site-packages (from click>=8.1.3->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('https://github.com/movcha/team_project/blob/main/data/mortgage.csv')

# Display the first few rows to understand the structure
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       3 # Load the dataset
# ----> 4 df = pd.read_csv('https://github.com/movcha/team_project/blob/main/data/mortgage.csv')
#       6 # Display the first few rows to understand the structure
#       7 print(df.head())
#
# File c:\Users\omovc\.conda\envs\dsi_participant\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\omovc\.conda\envs\dsi_participant\lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\omovc\.conda\envs\dsi_participant\lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Users\omovc\.conda\envs\dsi_participant\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 40, saw 26

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px

# Initialize the Dash app
app = dash.Dash(__name__)

# Define the layout of the app
app.layout = html.Div([
    html.H1("Interactive Risk Profile Dashboard"),

    # Dropdown for Income Category
    dcc.Dropdown(
        id='income-dropdown',
        options=[{'label': cat, 'value': cat} for cat in df['income_category'].unique()],
        value=df['income_category'].unique().tolist(),
        multi=True
    ),

    # Dropdown for Home Ownership
    dcc.Dropdown(
        id='home-ownership-dropdown',
        options=[{'label': ho, 'value': ho} for ho in df['home_ownership'].unique()],
        value=df['home_ownership'].unique().tolist(),
        multi=True
    ),

    # Dropdown for Loan Term
    dcc.Dropdown(
        id='loan-term-dropdown',
        options=[{'label': term, 'value': term} for term in df['term'].unique()],
        value=df['term'].unique().tolist(),
        multi=True
    ),

    # Graph for visualizing the filtered data
    dcc.Graph(id='risk-profile-graph')
])

# Define the callback to update the graph based on the dropdown selections
@app.callback(
    Output('risk-profile-graph', 'figure'),
    [
        Input('income-dropdown', 'value'),
        Input('home-ownership-dropdown', 'value'),
        Input('loan-term-dropdown', 'value')
    ]
)
def update_graph(selected_income, selected_home_ownership, selected_loan_term):
    filtered_df = df[
        df['income_category'].isin(selected_income) &
        df['home_ownership'].isin(selected_home_ownership) &
        df['term'].isin(selected_loan_term)
    ]

    # Create a scatter plot with Plotly Express
    fig = px.scatter(
        filtered_df,
        x='annual_inc',
        y='loan_amount',
        color='loan_condition',
        title="Loan Amount vs. Annual Income",
        labels={"annual_inc": "Annual Income", "loan_amount": "Loan Amount"}
    )

    # Update layout for better readability
    fig.update_layout(
        xaxis_title='Annual Income',
        yaxis_title='Loan Amount',
        legend_title='Loan Condition'
    )

    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# C:\Users\14372\AppData\Local\Temp\ipykernel_2676\4113816876.py:2: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\14372\AppData\Local\Temp\ipykernel_2676\4113816876.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Running the App :
# Step 1 -
# Save this script as app.py and run it from bash terminal >>
#
# python app.ipynb
#
# Step 2 -
# Access the interactive dashboard at http://127.0.0.1:8050/

# %% [markdown]
# Visualization 2 :

# %% [markdown]
# Correlation matrix heatmap-
# To showcase relationships between different variables (e.g., interest rate, dti, income, loan amount) and loan conditions and provide insights on how different variables correlate with loan conditions and identify key factors influencing loan risk.

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encode categorical columns
df['home_ownership_encoded'] = label_encoder.fit_transform(df['home_ownership'])
df['income_category_encoded'] = label_encoder.fit_transform(df['income_category'])
df['loan_condition_encoded'] = label_encoder.fit_transform(df['loan_condition'])

# Display the DataFrame with encoded columns
print(df.head())
# Out:
#         id  year     issue_d  final_d  emp_length_int home_ownership  \
# 0  1062177  2011  01/12/2011  1062013             2.0       MORTGAGE
# 1  1049352  2011  01/12/2011  1042013             1.0       MORTGAGE
# 2  1062976  2011  01/12/2011  1042013            10.0           RENT
# 3  1058564  2011  01/12/2011  1122014             6.0           RENT
# 4  1061837  2011  01/12/2011  1122014             7.0           RENT
#
#   income_category  annual_inc  income_cat  loan_amount  ... grade_cat    dti  \
# 0             Low       44400           1        15000  ...         4   3.59
# 1             Low      100000           1         6600  ...         2  15.53
# 2             Low       45000           1         4000  ...         5  15.20
# 3             Low       57600           1         8000  ...         1  11.52
# 4             Low       60000           1        15000  ...         1  12.78
#
#     total_pymnt total_rec_prncp  recoveries installment        region  \
# 0  17991.530000        15000.00        0.00      536.81      leinster
# 1   7274.620000         6600.00        0.00      212.69      leinster
# 2   1775.800000          660.29      191.14      105.78  Northern-Irl
# 3   8765.098071         8000.00        0.00      243.49        ulster
# 4  16434.538010        15000.00        0.00      456.54  Northern-Irl
#
#    home_ownership_encoded income_category_encoded  loan_condition_encoded
# 0                       0                       1                       1
# 1                       0                       1                       1
# 2                       3                       1                       0
# 3                       3                       1                       1
# 4                       3                       1                       1
#
# [5 rows x 29 columns]

# %%
# Select numerical columns including encoded ones
numerical_df = df[['annual_inc', 'loan_amount', 'interest_rate', 'dti', 'home_ownership_encoded', 'income_category_encoded', 'loan_condition_encoded']]

# Calculate the correlation matrix
corr_matrix = numerical_df.corr()

# Display the correlation matrix
print(corr_matrix)
# Out:
#                          annual_inc  loan_amount  interest_rate       dti  \
# annual_inc                 1.000000     0.448802      -0.046938 -0.240445
# loan_amount                0.448802     1.000000       0.124681 -0.117306
# interest_rate             -0.046938     0.124681       1.000000  0.204087
# dti                       -0.240445    -0.117306       0.204087  1.000000
# home_ownership_encoded    -0.132741    -0.148310       0.110455  0.031725
# income_category_encoded    0.112003     0.187335      -0.052455 -0.089661
# loan_condition_encoded     0.081224     0.000517      -0.124773 -0.062724
#
#                          home_ownership_encoded  income_category_encoded  \
# annual_inc                            -0.132741                 0.112003
# loan_amount                           -0.148310                 0.187335
# interest_rate                          0.110455                -0.052455
# dti                                    0.031725                -0.089661
# home_ownership_encoded                 1.000000                -0.100140
# income_category_encoded               -0.100140                 1.000000
# loan_condition_encoded                -0.003478                 0.020418
#
#                          loan_condition_encoded
# annual_inc                             0.081224
# loan_amount                            0.000517
# interest_rate                         -0.124773
# dti                                   -0.062724
# home_ownership_encoded                -0.003478
# income_category_encoded                0.020418
# loan_condition_encoded                 1.000000

# %% [markdown]
# The heatmap uses colors to represent correlation values. Darker colors often indicate stronger correlations.
# We will look for strong correlations (close to 1 or -1) between variables and loan conditions.
#
# For example, if interest_rate has a high negative correlation with loan_condition_encoded, it may indicate that higher interest rates are associated with worse loan conditions.

# %%
import plotly.express as px
import plotly.graph_objects as go

# Create the heatmap
fig = go.Figure(data=go.Heatmap(
    z=corr_matrix.values,
    x=corr_matrix.columns,
    y=corr_matrix.columns,
    colorscale='Viridis',
    colorbar=dict(title='Correlation')
))

# Update layout for better readability
fig.update_layout(
    title='Correlation Matrix Heatmap',
    xaxis_title='Variables',
    yaxis_title='Variables',
    xaxis=dict(tickvals=list(range(len(corr_matrix.columns))), ticktext=corr_matrix.columns),
    yaxis=dict(tickvals=list(range(len(corr_matrix.columns))), ticktext=corr_matrix.columns)
)

# Show the heatmap
fig.show()
